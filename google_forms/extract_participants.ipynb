# %%
import pandas as pd

# %%
survey_df = pd.read_csv(r"C:\Users\ercj\Desktop\plain_language_summarization_platform\google_forms\surveys\Health Information Survey_0301.csv")
prolific_df = pd.read_csv(r"C:\Users\ercj\Desktop\plain_language_summarization_platform\google_forms\static_1\survey_2_0301.csv")

# %%
new_df = survey_df[survey_df["Participant id"].isin(prolific_df["Participant id"])]

# %%
new_df.to_csv(r"C:\Users\ercj\Desktop\plain_language_summarization_platform\google_forms\static_1\0301_filtered_combined_survey_2.csv")
