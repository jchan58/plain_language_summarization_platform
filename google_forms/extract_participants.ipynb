# %%
import pandas as pd

# %%
survey_df = pd.read_csv(r"C:\Users\ercj\Desktop\plain_language_summarization_platform\google_forms\health_survey_2_responses_0225.csv")
prolific_df = pd.read_csv(r"C:\Users\ercj\Desktop\plain_language_summarization_platform\prolific_data\prolific_survey_2_53_completed_0225.csv")

# %%
new_df = survey_df[survey_df["Participant id"].isin(prolific_df["Participant id"])]

# %%
new_df.to_csv(r"C:\Users\ercj\Desktop\plain_language_summarization_platform\google_forms\static_1\0225.csv")
