    "57a93244dcff7d0001c7d86f",
    "5e2ac2aa0038f21089a533a4",
    "63bf40687b33e43442effb9b",
    "62fe6312269d0e4ae894297b",
    "6643bed0ed868a9901a9ddec",
    "66293f7d355cb2780b2b2ab1",
    "6630f318d0d884cf785e436f",
    "66757cddd8d92a5cbfda353f",
    "64ef5620f0a6cf6a9568a4b4",
    "6685cec5c360283099e5bb29",
    "63ecf8c3796bf9efcf715050",
]

# %%
remaining_users = [x for x in study_2_users if x not in already_completed]

# %%
with open("remaining_not_completed_survey_2.txt", "w") as f:
    for user_id in remaining_users:
        f.write(user_id + "\n")

# %%
# overlap between two files 
approved_ids = pd.read_csv(r"C:\Users\ercj\Desktop\plain_language_summarization_platform\approved_ids.csv")
approved_set = set(approved_ids['prolific_id'])

# %%
not_approved_users = [x for x in remaining_users if x not in approved_set]
overlap = [x for x in remaining_users if x in approved_set]

# %%
print("Remaining users:", len(remaining_users))
print("Approved overlap:", len(overlap))
print("Not approved:", len(not_approved_users))
# Out:
# Remaining users: 148
# Approved overlap: 0
# Not approved: 148

# %%
from pymongo import MongoClient
from bson import json_util
import json

client = MongoClient("mongodb+srv://jchan51_db_user:Aliciarivera2%40@cluster0.hxeytkt.mongodb.net/")
db = client["pls"]
users_collection = db["users"]

data = list(users_collection.find({}, {"_id": 0}))

with open("pls_users_export_0306.json", "w") as f:
    json.dump(data, f, indent=2, default=json_util.default)

print("Export complete")
# Out:
# Export complete

# %%
import math

users_with_nan = []

for user in data:
    pid = user["prolific_id"]

    for phase in user.get("phases", {}).values():
        for batch in phase.get("batches", {}).values():
            for abs_id, abstract in batch.get("abstracts", {}).items():

                for k, v in abstract.items():
                    if isinstance(v, float) and math.isnan(v):
                        users_with_nan.append({
                            "prolific_id": pid,
                            "abstract_id": abs_id,
                            "field": k
                        })

users_with_nan
# Out:
# [{'prolific_id': '616cf9ae07c1c6bd05d95beb',
#   'abstract_id': '1062',
#   'field': 'question_5'},
#  {'prolific_id': '616cf9ae07c1c6bd05d95beb',
#   'abstract_id': '1062',
#   'field': 'question_5_answers_choices'},
#  {'prolific_id': '616cf9ae07c1c6bd05d95beb',
#   'abstract_id': '1062',
#   'field': 'question_5_correct_answers'},
#  {'prolific_id': '69879891942c84487315e3c8',
#   'abstract_id': '1068',
#   'field': 'question_5'},
#  {'prolific_id': '69879891942c84487315e3c8',
#   'abstract_id': '1068',
#   'field': 'question_5_answers_choices'},
#  {'prolific_id': '69879891942c84487315e3c8',
#   'abstract_id': '1068',
#   'field': 'question_5_correct_answers'},
#  {'prolific_id': '5e27868c5cbbcc0b3599574b',
#   'abstract_id': '1068',
#   'field': 'question_5'},
#  {'prolific_id': '5e27868c5cbbcc0b3599574b',
#   'abstract_id': '1068',
#   'field': 'question_5_answers_choices'},
#  {'prolific_id': '5e27868c5cbbcc0b3599574b',
#   'abstract_id': '1068',
# ...
