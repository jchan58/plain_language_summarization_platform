# %%
import pandas as pd

# %%
final_df = pd.read_csv(r"C:\Users\ercj\Desktop\plain_language_summarization_platform\final_user_batches.csv")
final_df.columns
# Out:
# Index(['user_id', 'type', 'abstract_title', 'abstract', 'human_written',
#        'abstract_id', 'terms', 'question_1', 'question_2', 'question_3',
#        'question_4', 'question_5', 'question_1_answers_choices',
#        'question_1_correct_answers', 'question_2_answers_choices',
#        'question_2_correct_answers', 'question_3_answers_choices',
#        'question_3_correct_answers', 'question_4_answers_choices',
#        'question_4_correct_answers', 'question_5_answers_choices',
#        'question_5_correct_answers'],
#       dtype='object')

# %%
final_df["type"] = final_df["type"].replace("interactive_4", "interactive_3")
print(final_df["type"].value_counts())
final_df.to_csv(
    r"C:\Users\ercj\Desktop\plain_language_summarization_platform\final_user_batches.csv",
    index=False
)
# Out:
# type
# interactive_3    336
# finetuned_6      224
# static_2         224
# static_1         112
# finetuned_5      112
# Name: count, dtype: int64
